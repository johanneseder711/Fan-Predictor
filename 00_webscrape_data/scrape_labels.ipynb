# %%
# IMPORTS
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import re

# %%
# define some sample URLS to test the data gathering
# the urls we taken s.t. we then later just need to add the current round where we can extract important information like standings
# but also it is the starting point where we find the link to the detailed matches to extract more data and labels :)

ligen_urls = {
    '2 Klasse Yspertal/AV': "https://www.oefb.at/bewerbe/Bewerb/208719/Runde-",
    '2 Klasse Ybbstal/AV': "https://www.oefb.at/bewerbe/Bewerb/208687/Runde-",
    '1 Klasse Nord': "https://www.oefb.at/bewerbe/Bewerb/208682/Runde-",
    '1 Klasse Ost': 'https://www.oefb.at/bewerbe/Bewerb/208710/Runde-',
    '1 Klasse Waldviertel': "https://www.oefb.at/bewerbe/Bewerb/208684/Runde-",
    '1 Klasse Süd': "https://www.oefb.at/bewerbe/Bewerb/208697/Runde-",
    '1 Klasse West': "https://www.oefb.at/bewerbe/Bewerb/208693/Runde-",
    '1 Klasse Nordwest': "https://www.oefb.at/bewerbe/Bewerb/208713/Runde-",
    'Gebietsliga Nord/Nordwest': "https://www.oefb.at/bewerbe/Bewerb/208717/Runde-",
    'Gebietsliga Nordwest/Waldviertel': "https://www.oefb.at/bewerbe/Bewerb/208680/Runde-",
    'Gebietsliga Süd/Südost': "https://www.oefb.at/bewerbe/Bewerb/208695/Runde-",
    'Gebietsliga West': "https://www.oefb.at/bewerbe/Bewerb/208708/Runde-",
    '2 Landesliga Ost': "https://www.oefb.at/bewerbe/Bewerb/208714/Runde-",
    '2 Landesliga West': "https://www.oefb.at/bewerbe/Bewerb/208715/Runde-",
    '1 Landesliga': "https://www.oefb.at/bewerbe/Bewerb/208685/Runde-"
}

# %%
def wait_for_full_load(driver, path, how='xpath'):
    '''
    A function that takes in an xpath of an element and a driver (browser).
    The function will be exited as soon as the element is available on the site.
    '''
    waiting = True
    while waiting:
        # check if at least one element is already available on the site
        if how == 'xpath': 
            elements = driver.find_elements(By.XPATH, path)
            print(len(elements))
        elif how == 'css':
            elements = driver.find_elements(By.CSS_SELECTOR, path)
        elif how == 'id':
            elements = driver.find_elements(By.ID, path)
        
        if len(elements)!=0: 
            waiting = False
            return;
        else:
            time.sleep(1)

# %%
# %%time

# create the df to store the data in 
df = pd.DataFrame(columns=['Liga','Round','Matchday Date','Hometeam','Hometeam Standing','Hometeam points','Awayteam','Awayteam Standing','Awayteam points','Matchday Time','Fans watching','Match location'])

# start the session
driver = webdriver.Safari()
#driver.maximize_window()

# get some URL to accept the cookies on that website
driver.get(ligen_urls["1 Klasse West"])
cookies_xpath_preferences = """//*[@id="app-instance-1582128784421-0"]/div/div/div/form/div[4]/input[1]"""
wait_for_full_load(driver, cookies_xpath_preferences)
driver.find_element(By.XPATH, cookies_xpath_preferences).click()

# iterate over each league
for liga in ligen_urls.keys():
    print("#"*10,liga.upper(),"#"*10,'\n')
    
    # iterate over the first two rounds to test
    for i in range(25):
        print('-'*5,f"RUNDE {i+1}",'-'*5,'\n')
        # open current round website
        driver.get(ligen_urls[liga] + str(i+1))
        
        # if the matches have already been played there exists a link to the match summary = Spielbericht
        elems = driver.find_elements(By.XPATH, f"//a[@title='Spielbericht']")
        
        print(f'Es konnten in der aktuellen Runde {len(elems)} Spielberichte gefunden werden!\n')

        # if there have been matches played in that round we can continue the data extraction
        if len(elems) != 0:
            # before followin the urls to the detailed match site we extract the standings and point 
            # ATTENTION: since we deal with historical data, this data we now extract are already the standings after that round was played
            # therefore we need this data only as input for the next round (which means before the next round was played)
            # example: for round 1 we have everybody with 0 points, which will be our d_act for i == 0
            # but for the next round we store the standings after round 1 as input
            stats_teams = [elem.get_attribute('title') for elem in driver.find_elements(By.CLASS_NAME, "m_g_team_only_1")]
            stats_points = [elem.text for elem in driver.find_elements(By.CLASS_NAME, "m_g_points_1")]
            # the default when no games played yet
            if i == 0: 
                # first match -> everybody has 0 points and is in the middle position (//2) of the table
                d_act = dict((val, [len(stats_teams)//2, 0]) for val in stats_teams)
            
            # save the stats as input for the next round
            d_next = dict((val, [p+1, stats_points[p]]) for p, val in enumerate(stats_teams))

            # extract the links to the match summaries and iterate over them
            hrefs = [elm.get_attribute('href') for elm in elems]
            for href in hrefs:
                # create array to store the data
                l = []

                # append liga information
                l.append(liga)

                # open the new website
                driver.get(href)

                # get round of the season
                l.append(driver.find_element(By.XPATH, """//*[@id="app-instance-5595842886476943452-1475120657383348073"]/div/div[1]""").text)

                # get time of the matchstart
                l.append(driver.find_element(By.XPATH, """//*[@id="app-instance-5595842886476943452-1475120657383348073"]/div/div[2]""").text)

                # get team playing at home
                hometeam = driver.find_element(By.XPATH, """//*[@id="app-instance-5595842886476943452-1475120657383348073"]/div/div[3]/a[1]/span""").text
                l.append(hometeam)
                if hometeam not in d_act.keys():
                    print(f"Hometeam {hometeam} not found in dict keys\n")
                    hometeam = [team for team in d_act.keys() if hometeam in team][0]
                    print(f"Hometeam has dict key name {hometeam}!\n")

                # hometeam place and points
                l.append(d_act[hometeam][0])
                l.append(d_act[hometeam][1])
                
                # get team playing at outwards
                awayteam = driver.find_element(By.XPATH, """//*[@id="app-instance-5595842886476943452-1475120657383348073"]/div/div[3]/a[2]/span""").text
                l.append(awayteam)
                if awayteam not in d_act.keys():
                    print(f"Hometeam {awayteam} not found in dict keys\n")
                    awayteam = [team for team in d_act.keys() if awayteam in team][0]
                    print(f"Hometeam has dict key name {awayteam}!\n")
                
                # awayteam place and points
                l.append(d_act[awayteam][0])
                l.append(d_act[awayteam][1])
                
                # get start of the matchtime
                l.append(driver.find_element(By.XPATH, """//*[@id="app-instance-5595842886476943452-1475120657383348073"]/div/div[4]/div[3]/div[1]/span[2]""").text)

                # get fans that watched the game
                l.append(driver.find_element(By.XPATH, """//*[@id="app-instance-5595842886476943452-1475120657383348073"]/div/div[4]/div[3]/div[3]/span[2]""").text)

                # open the new website to scrap location data
                driver.get(href.replace('Spielbericht', 'Spielort'))
                
                # get location of the match
                l.append(driver.find_element(By.XPATH, """//*[@class="game_place_content_1"]""").text)
                
                # append array as last row to df
                df.loc[len(df)] = l
            
            # set the actual standings as input for the next game
            d_act = d_next
        
        # if no game was played in that round we continue with the next round
        else:
            continue
    
# close driver
driver.quit()
# Out:
# 1
# ########## 1 KLASSE WALDVIERTEL ##########
#
# ----- RUNDE 1 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 2 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 3 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 4 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 5 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 6 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 7 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 8 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 9 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 10 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 11 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 12 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 13 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 14 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 15 -----
#
# Es konnten in der aktuellen Runde 8 Spielberichte gefunden werden!
#
# ----- RUNDE 16 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 17 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 18 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 19 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 20 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 21 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 22 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 23 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 24 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ----- RUNDE 25 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ########## 1 KLASSE SÜD ##########
#
# ----- RUNDE 1 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 2 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 3 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 4 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 5 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 6 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 7 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 8 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 9 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 10 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 11 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 12 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 13 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 14 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 15 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 16 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 17 -----
#
# Es konnten in der aktuellen Runde 8 Spielberichte gefunden werden!
#
# ----- RUNDE 18 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 19 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 20 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 21 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 22 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 23 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 24 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ----- RUNDE 25 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ########## 1 KLASSE WEST ##########
#
# ----- RUNDE 1 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 2 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 3 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 4 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 5 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 6 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 7 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 8 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 9 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 10 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 11 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 12 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 13 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 14 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 15 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 16 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 17 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 18 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 19 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 20 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 21 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 22 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 23 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 24 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ----- RUNDE 25 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ########## 1 KLASSE NORDWEST ##########
#
# ----- RUNDE 1 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 2 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 3 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 4 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 5 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 6 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 7 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 8 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 9 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 10 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 11 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 12 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 13 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 14 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 15 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 16 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 17 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 18 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 19 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 20 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 21 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 22 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 23 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 24 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ----- RUNDE 25 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ########## GEBIETSLIGA NORD/NORDWEST ##########
#
# ----- RUNDE 1 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 2 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 3 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 4 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 5 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 6 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 7 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 8 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 9 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 10 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 11 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 12 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 13 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 14 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 15 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 16 -----
#
# Es konnten in der aktuellen Runde 6 Spielberichte gefunden werden!
#
# ----- RUNDE 17 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 18 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 19 -----
#
# Es konnten in der aktuellen Runde 6 Spielberichte gefunden werden!
#
# ----- RUNDE 20 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 21 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 22 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 23 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 24 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ----- RUNDE 25 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ########## GEBIETSLIGA NORDWEST/WALDVIERTEL ##########
#
# ----- RUNDE 1 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 2 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 3 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 4 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 5 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 6 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 7 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 8 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 9 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 10 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 11 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 12 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 13 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 14 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 15 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 16 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 17 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 18 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 19 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 20 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 21 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 22 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 23 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 24 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ----- RUNDE 25 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ########## GEBIETSLIGA SÜD/SÜDOST ##########
#
# ----- RUNDE 1 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 2 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 3 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 4 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 5 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 6 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 7 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 8 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 9 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 10 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 11 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 12 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 13 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 14 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 15 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 16 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 17 -----
#
# Es konnten in der aktuellen Runde 8 Spielberichte gefunden werden!
#
# ----- RUNDE 18 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 19 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 20 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 21 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 22 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 23 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 24 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ----- RUNDE 25 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ########## GEBIETSLIGA WEST ##########
#
# ----- RUNDE 1 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 2 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 3 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 4 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 5 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 6 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 7 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 8 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 9 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 10 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 11 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 12 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 13 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 14 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 15 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 16 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 17 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 18 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 19 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 20 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 21 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 22 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 23 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 24 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ----- RUNDE 25 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ########## 2 LANDESLIGA OST ##########
#
# ----- RUNDE 1 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 2 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 3 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 4 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 5 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 6 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 7 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 8 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 9 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 10 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 11 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 12 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 13 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 14 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 15 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 16 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 17 -----
#
# Es konnten in der aktuellen Runde 6 Spielberichte gefunden werden!
#
# ----- RUNDE 18 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 19 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 20 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 21 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 22 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 23 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 24 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ----- RUNDE 25 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ########## 2 LANDESLIGA WEST ##########
#
# ----- RUNDE 1 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 2 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 3 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 4 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 5 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 6 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 7 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 8 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 9 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 10 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 11 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 12 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 13 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 14 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 15 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 16 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 17 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 18 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 19 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 20 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 21 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 22 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 23 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 24 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ----- RUNDE 25 -----
#
# Es konnten in der aktuellen Runde 0 Spielberichte gefunden werden!
#
# ########## 1 LANDESLIGA ##########
#
# ----- RUNDE 1 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 2 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 3 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 4 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 5 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 6 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 7 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 8 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 9 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 10 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 11 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 12 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 13 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 14 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 15 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 16 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 17 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 18 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 19 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 20 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 21 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 22 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 23 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 24 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# ----- RUNDE 25 -----
#
# Es konnten in der aktuellen Runde 7 Spielberichte gefunden werden!
#
# CPU times: user 54.2 s, sys: 6.05 s, total: 1min
# Wall time: 9h 12min 55s

# %%
df.head(10)
# Out:
#                    Liga     Round Matchday Date            Hometeam  \
# 0  1 Klasse Waldviertel  1. Runde    15.08.2021    Heidenreichstein
# 1  1 Klasse Waldviertel  1. Runde    15.08.2021       Pfaffenschlag
# 2  1 Klasse Waldviertel  1. Runde    14.08.2021      Rappottenstein
# 3  1 Klasse Waldviertel  1. Runde    14.08.2021       Großsiegharts
# 4  1 Klasse Waldviertel  1. Runde    14.08.2021  SG Brand/Nagelberg
# 5  1 Klasse Waldviertel  1. Runde    14.08.2021          St. Martin
# 6  1 Klasse Waldviertel  1. Runde    13.08.2021               Vitis
# 7  1 Klasse Waldviertel  2. Runde    22.08.2021          Dobersberg
# 8  1 Klasse Waldviertel  2. Runde    22.08.2021              Weitra
# 9  1 Klasse Waldviertel  2. Runde    22.08.2021    Heidenreichstein
#
#    Hometeam Standing Hometeam points            Awayteam  Awayteam Standing  \
# 0                  7               0             Gastern                  7
# 1                  7               0            Litschau                  7
# 2                  7               0         Windigsteig                  7
# 3                  7               0          Dobersberg                  7
# 4                  7               0              Weitra                  7
# 5                  7               0           Raxendorf                  7
# 6                  7               0             Kautzen                  7
# 7                 11               0          St. Martin                 10
# 8                  6               3               Vitis                  7
# 9                 14               0  SG Brand/Nagelberg                  8
#
#   Awayteam points Matchday Time Fans watching  \
# 0               0         17:30           205
# 1               0         17:30           250
# 2               0         19:00            56
# 3               0         17:30           150
# 4               0         17:30           100
# 5               0         17:30           110
# 6               0         19:30           100
# 7               0         17:00           100
# 8               3         17:00           150
# 9               0         11:00           150
#
#                                       Match location
# 0  \n\t\tAdresse & Anfahrt\n\t\tin Heidenreichste...
# 1  \n\t\tAdresse & Anfahrt\n\t\tSportplatz Pfaffe...
# 2  \n\t\tAdresse & Anfahrt\n\t\tin Rappottenstein...
# 3  \n\t\tAdresse & Anfahrt\n\t\tin Gr. Siegharts/...
# 4  \n\t\tAdresse & Anfahrt\n\t\tin Brand/ Birkens...
# 5  \n\t\tAdresse & Anfahrt\n\t\tSportplatz St. Ma...
# 6  \n\t\tAdresse & Anfahrt\n\t\tSportplatz 1. SV ...
# 7  \n\t\tAdresse & Anfahrt\n\t\tSportplatz Dobers...
# 8  \n\t\tAdresse & Anfahrt\n\t\tin Weitra/ Braust...
# 9  \n\t\tAdresse & Anfahrt\n\t\tin Heidenreichste...

# %%
df.tail(10)
# Out:
#               Liga      Round Matchday Date                     Hometeam  \
# 1775  1 Landesliga  24. Runde    06.05.2022                   SC Ortmann
# 1776  1 Landesliga  24. Runde    06.05.2022                 SCU Ardagger
# 1777  1 Landesliga  24. Runde    06.05.2022                 USC Rohrbach
# 1778  1 Landesliga  25. Runde    14.05.2022                SC Mibag Retz
# 1779  1 Landesliga  25. Runde    14.05.2022                     SCU Kilb
# 1780  1 Landesliga  25. Runde    13.05.2022                    SC Zwettl
# 1781  1 Landesliga  25. Runde    13.05.2022                SV Langenrohr
# 1782  1 Landesliga  25. Runde    13.05.2022           SV Waidhofen/Thaya
# 1783  1 Landesliga  25. Runde    13.05.2022  USV Scheiblingkirchen-Warth
# 1784  1 Landesliga  25. Runde    12.05.2022       SKN St. Pölten Juniors
#
#       Hometeam Standing Hometeam points                Awayteam  \
# 1775                  6              29      SV Waidhofen/Thaya
# 1776                  4              33                SCU Kilb
# 1777                 10              22  SKN St. Pölten Juniors
# 1778                  3              40             ASV Schrems
# 1779                  8              28              Kremser SC
# 1780                 14              20        ASK Kottingbrunn
# 1781                 11              23         ASK Mannersdorf
# 1782                  7              29            SCU Ardagger
# 1783                  1              64            USC Rohrbach
# 1784                  5              33              SC Ortmann
#
#       Awayteam Standing Awayteam points Matchday Time Fans watching  \
# 1775                  7              29         19:30           150
# 1776                  8              28         19:30           248
# 1777                  5              30         19:30           166
# 1778                 13              20         16:30           250
# 1779                  2              53         15:00           350
# 1780                  9              27         19:30           290
# 1781                 15               9         19:30           250
# 1782                  4              36         19:30           250
# 1783                 12              22         19:30           300
# 1784                  6              32         20:00            77
#
#                                          Match location
# 1775  \n\t\tAdresse & Anfahrt\n\t\tSportplatz Ortman...
# 1776  \n\t\tAdresse & Anfahrt\n\t\tSportplatz SC Uni...
# 1777  \n\t\tAdresse & Anfahrt\n\t\tin Rohrbach-Gölse...
# 1778  \n\t\tAdresse & Anfahrt\n\t\tSportplatz Retz S...
# 1779  \n\t\tAdresse & Anfahrt\n\t\tin Kilb/ Waldstad...
# 1780  \n\t\tAdresse & Anfahrt\n\t\tin Zwettl/ Sporta...
# 1781  \n\t\tAdresse & Anfahrt\n\t\tSportplatz SV Lan...
# 1782  \n\t\tAdresse & Anfahrt\n\t\tin Waidhofen-Thay...
# 1783  \n\t\tAdresse & Anfahrt\n\t\tPittentalstadion ...
# 1784  \n\t\tAdresse & Anfahrt\n\t\tin St. Pölten-Sta...

# %%
# export data to csv
df.to_csv('data.csv', sep=";", index=False)
